# %% [markdown]
# # Storytelling with Data Viz on Exchange Rates

# %% [markdown]
# ## The Data

# %% [markdown]
# The dataset we'll use describes Euro daily exchange rates between 1999 and 2021.
#
# Our focus in the guided part of the project will be on the exchange rate between the euro and the American dollar.
#
# If the exchange rate of the euro to the US dollar is 1.5, you get 1.5 US dollars if you pay 1.0 euro (one euro has more value than one US dollar at this exchange rate)

# %%
import pandas as pd

# import the data into a dataframe

exchange_rates = pd.read_csv('euro-daily-hist_1999_2020.csv')

# %%
# inspect the dataframe

exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2021-01-08               1.5758           1.9558            6.5748
# 1   2021-01-07               1.5836           1.9558            6.5172
# 2   2021-01-06               1.5824           1.9558            6.5119
# 3   2021-01-05               1.5927           1.9558            6.5517
# 4   2021-01-04               1.5928           1.9558            6.3241
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.5543         1.0827                   7.9184              NaN
# 1             1.5601         1.0833                   7.9392              NaN
# 2             1.5640         1.0821                   7.9653              NaN
# 3             1.5651         1.0803                   7.9315              NaN
# 4             1.5621         1.0811                   7.9484              NaN
#
# ...

# %%
exchange_rates.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 5694   1999-01-08               1.8406              NaN               NaN
# 5695   1999-01-07               1.8474              NaN               NaN
# 5696   1999-01-06               1.8820              NaN               NaN
# 5697   1999-01-05               1.8944              NaN               NaN
# 5698   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 5694             1.7643         1.6138                      NaN
# 5695             1.7602         1.6165                      NaN
# 5696             1.7711         1.6116                      NaN
# 5697             1.7965         1.6123                      NaN
# 5698             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# ...

# %%
exchange_rates.shape
# Out:
# (5699, 41)

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              5699 non-null   object
#  1   [Australian dollar ]      5699 non-null   object
#  2   [Bulgarian lev ]          5297 non-null   object
#  3   [Brazilian real ]         5431 non-null   object
#  4   [Canadian dollar ]        5699 non-null   object
#  5   [Swiss franc ]            5699 non-null   object
#  6   [Chinese yuan renminbi ]  5431 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           5699 non-null   object
#  9   [Danish krone ]           5699 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      5699 non-null   object
#  12  [Greek drachma ]          520 non-null    object
# ...

# %% [markdown]
# First observations:
#
# - 5699 rows/41 columns
#
# - Turkish lira, Romainan leu, Iceland krona, are float64 data types
# - The rest are object data types
#
# - We notice that there are a number of exchange rate pairs data series that contain null values.

# %% [markdown]
# ### Data Cleaning

# %%
# rename to make typing easier, convert 'Time' object to datetime

exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time'},
                      inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)

# %% [markdown]
# We focus on US_dollar

# %%
# isolate Time and US_dollar columns

euro_to_dollar = exchange_rates[['Time','US_dollar']]

euro_to_dollar.head()
# Out:
#         Time US_dollar
# 0 1999-01-04    1.1789
# 1 1999-01-05    1.1790
# 2 1999-01-06    1.1743
# 3 1999-01-07    1.1632
# 4 1999-01-08    1.1659

# %%
# investigate the distribution of unique values

euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1305     7
# 1.1797     6
#           ..
# 1.2571     1
# 1.2610     1
# 1.2651     1
# 1.2632     1
# 1.2193     1
# Name: US_dollar, Length: 3528, dtype: int64

# %% [markdown]
# We want to get rid of the character "-".

# %%
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']

# %%
euro_to_dollar['US_dollar'].value_counts()
# Out:
# 1.2276    9
# 1.1215    8
# 1.1305    7
# 1.3373    6
# 1.3532    6
#          ..
# 1.2571    1
# 1.2610    1
# 1.2651    1
# 1.2632    1
# 1.2193    1
# Name: US_dollar, Length: 3527, dtype: int64

# %% [markdown]
# Let's convert the US_dollar column to float:

# %%
euro_to_dollar["US_dollar"] = euro_to_dollar["US_dollar"].astype(float)

# %%
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5637 entries, 0 to 5698
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       5637 non-null   datetime64[ns]
#  1   US_dollar  5637 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 132.1 KB

# %% [markdown]
# #### Rolling Mean

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(euro_to_dollar["Time"], euro_to_dollar["US_dollar"])
plt.show()

# %% [markdown]
# If we want to only show the long-term trends in the exchange rate, we can use the rolling mean (moving average) to hide the daily variations.
#
# To accomplish this, we can use pandas.Series.rolling().mean() method.
#
# Let's calculate the rolling mean for US_dollar using a rolling window of 30 days and let's add this calculation to a new column called rolling_mean.

# %%
euro_to_dollar["rolling_mean"] = euro_to_dollar["US_dollar"].rolling(30).mean()

# %%
euro_to_dollar.head(40)
# Out:
#          Time  US_dollar  rolling_mean
# 0  1999-01-04     1.1789           NaN
# 1  1999-01-05     1.1790           NaN
# 2  1999-01-06     1.1743           NaN
# 3  1999-01-07     1.1632           NaN
# 4  1999-01-08     1.1659           NaN
# 5  1999-01-11     1.1569           NaN
# 6  1999-01-12     1.1520           NaN
# 7  1999-01-13     1.1744           NaN
# 8  1999-01-14     1.1653           NaN
# 9  1999-01-15     1.1626           NaN
# 10 1999-01-18     1.1612           NaN
# 11 1999-01-19     1.1616           NaN
# 12 1999-01-20     1.1575           NaN
# 13 1999-01-21     1.1572           NaN
# 14 1999-01-22     1.1567           NaN
# 15 1999-01-25     1.1584           NaN
# 16 1999-01-26     1.1582           NaN
# 17 1999-01-27     1.1529           NaN
# 18 1999-01-28     1.1410           NaN
# 19 1999-01-29     1.1384           NaN
# 20 1999-02-01     1.1338           NaN
# 21 1999-02-02     1.1337           NaN
# 22 1999-02-03     1.1337           NaN
# ...

# %% [markdown]
# ### Coming up with an Idea

# %% [markdown]
# - Our objective is to create a storytelling data visualisation with the data we have.
#
# - Then we need to choose the right graph type. One that gives our story the visual form it needs.
# - Our audience should also be familiar with the style of graph.
# - Next, we sketch the graph (pen and paper will do just fine) before we code anything.
#     - maximise data-ink ratio
#     - create visuals using Gestalt principles
#     - guide the audiences attention using pre-attentive attributes

# %% [markdown]
# One interesting idea is to investigate how the euro-dollar rate changed under the three previous US presidents (George W. Bush (January 20, 2001 - January 20, 2009), Barack Obama (January 20, 2009 - January 20, 2017), and Donald Trump (January 20, 2017- January 20, 2021)).
#
# Let's code this up!

# %% [markdown]
# ### The EUR/USD Exchange Rate under Bush, Obama, and Trump

# %% [markdown]
# Let's get the data series for the respective term dates.

# %%
all_presidents = euro_to_dollar[euro_to_dollar["Time"].between('2001-01-20', '2021-01-20')]

# %%
all_presidents.head()
# Out:
#           Time  US_dollar  rolling_mean
# 535 2001-01-22     0.9290      0.922910
# 536 2001-01-23     0.9407      0.924457
# 537 2001-01-24     0.9294      0.925787
# 538 2001-01-25     0.9146      0.926927
# 539 2001-01-26     0.9228      0.928413

# %%
all_presidents.tail()
# Out:
#            Time  US_dollar  rolling_mean
# 5694 2021-01-04     1.2296      1.211170
# 5695 2021-01-05     1.2271      1.212530
# 5696 2021-01-06     1.2338      1.213987
# 5697 2021-01-07     1.2276      1.215357
# 5698 2021-01-08     1.2250      1.216557

# %%
all_presidents["rolling_mean"].describe()
# Out:
# count    5109.000000
# mean        1.220156
# std         0.153235
# min         0.851393
# 25%         1.117930
# 50%         1.224303
# 75%         1.328317
# max         1.574333
# Name: rolling_mean, dtype: float64

# %%
bush = all_presidents[all_presidents["Time"].between('2001-01-20', '2009-01-20')]

# %%
obama = all_presidents[all_presidents["Time"].between('2009-01-21', '2017-01-20')]

# %%
trump = all_presidents[all_presidents["Time"].between('2017-01-21', '2021-01-20')]

# %%
# use FiveThirtyEight style

import matplotlib.style as style

style.use('fivethirtyeight')

# add subplots

plt.figure(figsize = (12, 6))

ax1 = plt.subplot(2, 3, 1)
ax2 = plt.subplot(2, 3, 2)
ax3 = plt.subplot(2, 3, 3)

ax4 = plt.subplot(2, 1, 2)

axes = [ax1, ax2, ax3, ax4]

# format subplots using statistics from above

for ax in axes:
    ax.set_ylim(0.8, 1.7)
    ax.set_yticks([1.0, 1.2, 1.4, 1.6])
    ax.set_yticklabels(['1.0', '1.2', '1.4', '1.6'], alpha = 0.3)
    ax.grid(alpha = 0.5)
    
    
# Colours for the presidents:

# Bush:   #ADE4DB
# Obama:  #F6BA6F
# Trump:  #6DA9E4

# Background: #FFEBEB
    
    
# plot Bush term

ax1.plot(bush["Time"], bush["rolling_mean"], color = '#ADE4DB')
ax1.set_xticklabels(['', '2001', '', '2003', '', '2005', '', '2007', '', '2009'], alpha = 0.3)
ax1.text(12300, 1.92, 'BUSH', fontsize = 18, weight = "bold", color = '#ADE4DB')
ax1.text(12000, 1.80, '(2001 - 2009)', weight = "bold", alpha = 0.3)

# plot Obama term

ax2.plot(obama["Time"], obama["rolling_mean"], color = '#F6BA6F')
ax2.set_xticklabels(['','2009','', '2011', '', '2013', '', '2015', '', '2017'], alpha = 0.3)
ax1.text(16000, 1.92, 'OBAMA', fontsize = 18, weight = "bold", color = '#F6BA6F')
ax1.text(15800, 1.80, '(2009 - 2017)', weight = "bold", alpha = 0.3)

ax3.plot(trump["Time"], trump["rolling_mean"], color = '#6DA9E4')
ax3.set_xticklabels(['2017','', '2018', '', '2019', '', '2020', '', '2021'], alpha = 0.3)
ax1.text(19800, 1.92, 'TRUMP', fontsize = 18, weight = "bold", color = '#6DA9E4')
ax1.text(19550, 1.80, '(2017 - 2021)', weight = "bold", alpha = 0.3)

# plot all terms

ax4.plot(bush["Time"], bush["rolling_mean"], color = '#ADE4DB')
ax4.plot(obama["Time"], obama["rolling_mean"], color = '#F6BA6F')
ax4.plot(trump["Time"], trump["rolling_mean"], color = '#6DA9E4')
ax4.set_xticks([])


# add title, subtitle

ax1.text(11000, 2.26, 'EURO-USD rate averaged 1.22 under the last three US presidents', fontsize = 20, weight = "bold")
ax1.text(11000, 2.14, 'EURO-USD exchange rates under George W. Bush, Barack Obama, and Donald Trump')

# add signature

ax4.text(10000, 0.65, '@DATAQUEST' + ' '*119 + 'Source: European Central Bank', color = "#f0f0f0", backgroundcolor = "#4d4d4d", size = 14)

plt.show()
# Out:
# C:\Users\Raphael\AppData\Local\Temp\ipykernel_10252\1578506667.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(['', '2001', '', '2003', '', '2005', '', '2007', '', '2009'], alpha = 0.3)
# C:\Users\Raphael\AppData\Local\Temp\ipykernel_10252\1578506667.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(['','2009','', '2011', '', '2013', '', '2015', '', '2017'], alpha = 0.3)
# C:\Users\Raphael\AppData\Local\Temp\ipykernel_10252\1578506667.py:52: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(['2017','', '2018', '', '2019', '', '2020', '', '2021'], alpha = 0.3)

# %% [markdown]
# ### Next Steps

# %% [markdown]
# - Create a graph for a different currency
# - Create a graph for multiple currencies - perhaps compare their evolution
# - Making the project ready by adopting the Dataquest style guide
